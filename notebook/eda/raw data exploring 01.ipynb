# %%
import os
import sys
import importlib

# %%
os.path.abspath('../..')
# Out:
# '/Users/ximingfeng/Tutorial/movie-review'

# %%
os.path.abspath(os.path.join('../..'))
# Out:
# '/Users/ximingfeng/Tutorial/movie-review'

# %%
sys.path
# Out:
# ['',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python35.zip',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5/plat-darwin',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5/lib-dynload',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages/IPython/extensions',
#  '/Users/ximingfeng/.ipython']

# %%
module_path = os.path.abspath(os.path.join('../..'))

# %%
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
sys.path
# Out:
# ['',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python35.zip',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5/plat-darwin',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5/lib-dynload',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages',
#  '/Users/ximingfeng/anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages/IPython/extensions',
#  '/Users/ximingfeng/.ipython',
#  '/Users/ximingfeng/Tutorial/movie-review']

# %%
import src.popcorn as popcorn

# %%
importlib.reload(popcorn)
popcorn_helper = popcorn.PopcornHelper(root_directory=module_path)

# %%
train_raw, test_raw = popcorn_helper.load_raw_data()

# %%
train_raw.head()
# Out:
#        id  sentiment                                             review
# 0  5814_8          1  With all this stuff going down at the moment w...
# 1  2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2  7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3  3630_4          0  It must be assumed that those who praised this...
# 4  9495_8          1  Superbly trashy and wondrously unpretentious 8...

# %%
test_raw.head()
# Out:
#          id                                             review
# 0  12311_10  Naturally in a film who's main themes are of m...
# 1    8348_2  This movie is a disaster within a disaster fil...
# 2    5828_4  All in all, this is a movie for kids. We saw i...
# 3    7186_2  Afraid of the Dark left me with the impression...
# 4   12128_7  A very accurate depiction of small time mob li...

# %%
sample_review = train_raw.iloc[0]["review"]

# %%
sample_review
# Out:
# "With all this stuff going down at the moment with MJ i've started listening to his music, watching the odd documentary here and there, watched The Wiz and watched Moonwalker again. Maybe i just want to get a certain insight into this guy who i thought was really cool in the eighties just to maybe make up my mind whether he is guilty or innocent. Moonwalker is part biography, part feature film which i remember going to see at the cinema when it was originally released. Some of it has subtle messages about MJ's feeling towards the press and also the obvious message of drugs are bad m'kay.<br /><br />Visually impressive but of course this is all about Michael Jackson so unless you remotely like MJ in anyway then you are going to hate this and find it boring. Some may call MJ an egotist for consenting to the making of this movie BUT MJ and most of his fans would say that he made it for the fans which if true is really nice of him.<br /><br />The actual feature film bit when it finally s
# ...

# %%
sample_review_cleaned = popcorn_helper.clean_sentence(sample_review, remove_stopwords=True)

# %%
sample_review_cleaned
# Out:
# ['stuff',
#  'go',
#  'moment',
#  'mj',
#  'start',
#  'listen',
#  'music',
#  'watch',
#  'odd',
#  'documentari',
#  'watch',
#  'wiz',
#  'watch',
#  'moonwalk',
#  'mayb',
#  'want',
#  'get',
#  'certain',
#  'insight',
#  'guy',
#  'thought',
#  'realli',
#  'cool',
#  'eighti',
#  'mayb',
#  'make',
#  'mind',
#  'whether',
#  'guilti',
#  'innoc',
#  'moonwalk',
#  'part',
#  'biographi',
#  'part',
#  'featur',
#  'film',
#  'rememb',
#  'go',
#  'see',
#  'cinema',
#  'origin',
#  'releas',
#  'subtl',
#  'messag',
#  'mj',
#  'feel',
#  'toward',
#  'press',
#  'also',
#  'obviou',
#  'messag',
#  'drug',
#  'bad',
#  'br',
#  'br',
#  'visual',
#  'impress',
#  'cours',
#  'michael',
#  'jackson',
#  'unless',
#  'remot',
#  'like',
#  'mj',
#  'anyway',
#  'go',
#  'hate',
#  'find',
#  'bore',
#  'may',
#  'call',
#  'mj',
#  'egotist',
#  'consent',
#  'make',
#  'movi',
#  'mj',
#  'fan',
#  'would',
#  'say',
#  'made',
#  'fan',
#  'true',
#  'realli',
#  'nice',
# ...

# %%
popcorn_helper.is_valid_word('worlds\\', remove_stopwords=False)
# Out:
# False

# %%
from nltk.corpus import stopwords

# %%
len(train_raw)
# Out:
# 25000

# %%
sentence_list_clean = popcorn_helper.clean_dtset(train_raw.head(), sentence_col_name="review")

# %%
corpora_dict = popcorn_helper.build_save_dictionary(sentence_list_clean)

# %%
print(popcorn_helper.doc_2_ids(sentence_list_clean, corpora_dict))
# Out:
# [[128, 58, 91, 90, 126, 79, 94, 146, 99, 36, 146, 151, 146, 92, 85, 145, 55, 21, 66, 61, 136, 114, 28, 41, 85, 83, 88, 148, 60, 65, 92, 103, 11, 103, 49, 51, 116, 58, 121, 23, 101, 115, 131, 86, 90, 50, 137, 111, 2, 98, 86, 38, 7, 15, 15, 144, 64, 29, 87, 68, 142, 117, 77, 90, 4, 58, 62, 53, 13, 84, 18, 90, 40, 26, 83, 93, 90, 48, 153, 120, 82, 48, 139, 114, 97, 15, 15, 0, 49, 51, 12, 52, 126, 89, 45, 124, 30, 122, 69, 107, 27, 112, 110, 38, 80, 145, 90, 32, 7, 10, 90, 102, 108, 96, 69, 107, 22, 113, 145, 105, 72, 132, 38, 43, 39, 85, 62, 90, 15, 15, 81, 28, 134, 77, 90, 141, 20, 118, 149, 125, 33, 122, 2, 35, 95, 104, 119, 19, 51, 71, 7, 122, 143, 35, 62, 152, 100, 70, 74, 1, 149, 17, 106, 25, 31, 15, 15, 14, 78, 93, 105, 77, 90, 100, 75, 3, 135, 105, 127, 6, 138, 57, 150, 86, 67, 90, 9, 16, 93, 56, 87, 68, 140, 100, 133, 105, 44, 59, 109, 60, 147, 5, 54, 130, 147, 72, 105, 34, 8, 24, 37, 72, 47, 42, 46, 97, 129, 61, 100, 123, 76, 63, 73], [159, 200, 197, 176, 166, 51, 183, 174, 175
# ...

# %%
my_sentence = "Cool being, what up"

# %%
my_sent_cleaned = popcorn_helper.clean_sentence(my_sentence, remove_stopwords=True)

# %%
print(my_sent_cleaned)
# Out:
# ['cool']

# %%
my_sent_idx = popcorn_helper.doc_2_ids([my_sent_cleaned, ["not_in_dict", "yes"]], corpora_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d8decdd318a6> in <module>()
# ----> 1 my_sent_idx = popcorn_helper.doc_2_ids([my_sent_cleaned, ["not_in_dict", "yes"]], corpora_dict)
#
# NameError: name 'popcorn_helper' is not defined

# %%
print(my_sent_idx)
# Out:
# [[28], [-1, -1]]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-44c1315aeb88> in <module>()
# ----> 1 print(corpora_dict[-1])
#
# ~/anaconda3/envs/tfdeeplearning/lib/python3.5/site-packages/gensim/corpora/dictionary.py in __getitem__(self, tokenid)
#     110             # recompute id->word accordingly
#     111             self.id2token = utils.revdict(self.token2id)
# --> 112         return self.id2token[tokenid]  # will throw for non-existent ids
#     113
#     114     def __iter__(self):
#
# KeyError: -1

# %%
corpora_dict

# %%
corpora_dict.token2id
# Out:
# {'accent': 499,
#  'actor': 367,
#  'actual': 0,
#  'add': 368,
#  'addit': 202,
#  'afoul': 203,
#  'agent': 204,
#  'agre': 154,
#  'allow': 369,
#  'alon': 1,
#  'also': 2,
#  'altogeth': 370,
#  'amateur': 155,
#  'ambit': 205,
#  'amforta': 371,
#  'andrew': 372,
#  'angel': 206,
#  'anim': 207,
#  'anoth': 3,
#  'anyth': 373,
#  'anyway': 4,
#  'anywher': 374,
#  'appear': 208,
#  'appreci': 156,
#  'appropri': 209,
#  'area': 210,
#  'armin': 375,
#  'assum': 376,
#  'astound': 211,
#  'ate': 377,
#  'attack': 212,
#  'attent': 5,
#  'attract': 500,
#  'aural': 378,
#  'australian': 213,
#  'averag': 214,
#  'away': 6,
#  'babe': 379,
#  'bad': 7,
#  'badli': 215,
#  'baffl': 380,
#  'bare': 501,
#  'barrel': 216,
#  'base': 157,
#  'batonzilla': 381,
#  'battl': 502,
#  'bayreuth': 382,
#  'bc': 217,
#  'beast': 218,
#  'beat': 503,
#  'beatnik': 383,
#  'becom': 219,
#  'begin': 220,
#  'behead': 221,
#  'behind': 8,
#  'bell': 222,
#  'bestest': 9,
#  'bet': 504,
# ...
